# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#importing  excel file
file=pd.read_excel('C:/Users/RHESUS MONKEY/Desktop/New folder (2)/SHG_Booking_Data.xlsx')
file
# Out:
#         Booking ID   Hotel Booking Date Arrival Date  Lead Time  Nights  \
# 0                1  Resort   2014-07-24   2015-07-01        342       0
# 1                2  Resort   2013-06-24   2015-07-01        737       0
# 2                3  Resort   2015-06-24   2015-07-01          7       1
# 3                4  Resort   2015-06-18   2015-07-01         13       1
# 4                5  Resort   2015-06-17   2015-07-01         14       2
# ...            ...     ...          ...          ...        ...     ...
# 119385      119386    City   2017-08-07   2017-08-30         23       7
# 119386      119387    City   2017-05-21   2017-08-31        102       7
# 119387      119388    City   2017-07-28   2017-08-31         34       7
# 119388      119389    City   2017-05-14   2017-08-31        109       7
# 119389      119390    City   2017-02-05   2017-08-29        205       9
#
#         Guests  Distribution Channel Customer Type         Country  \
# ...

# %%
pd.set_option('precision', 2)
file.describe()
# Out:
#        Booking ID  Lead Time     Nights     Guests  Avg Daily Rate  \
# count   119390.00  119390.00  119390.00  119390.00       119390.00
# mean     59695.50     104.01       3.43       1.97          101.83
# std      34465.07     106.86       2.56       0.72           50.54
# min          1.00       0.00       0.00       0.00           -6.38
# 25%      29848.25      18.00       2.00       2.00           69.29
# 50%      59695.50      69.00       3.00       2.00           94.58
# 75%      89542.75     160.00       4.00       2.00          126.00
# max     119390.00     737.00      69.00      55.00         5400.00
#
#        Cancelled (0/1)    Revenue  Revenue Loss  Unnamed: 17
# count        119390.00  119390.00     119390.00          0.0
# mean              0.37     247.93       -109.92          NaN
# std               0.48     300.92        277.10          NaN
# min               0.00     -63.80      -6300.00          NaN
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#importing  excel file
file=pd.read_excel('C:/Users/RHESUS MONKEY/Desktop/New folder (2)/SHG_Booking_Data.xlsx')
booking_id=file['Booking ID']
hotel=file['Hotel']
guests=file['Guest']
nights=file['Night']
avg_daily_rate=['average daily rate']
cancelled=['Cancelled']
revenue=file['Revenue']
revenue_loss=['Revenue Loss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Guest'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-773c0af0d345> in <module>
#       8 booking_id=file['Booking ID']
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#importing  excel file
file=pd.read_excel('C:/Users/RHESUS MONKEY/Desktop/New folder (2)/SHG_Booking_Data.xlsx')
booking_id=file['Booking ID']
hotel=file['Hotel']
guests=file['Guests']
nights=file['Nights']
avg_daily_rate=['Avg daily rate']
cancelled=['Cancelled']
revenue=file['Revenue']
revenue_loss=['Revenue Loss']



revenue
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: Revenue, Length: 119390, dtype: float64

# %%
values,frequencies=np.unique(hotel, revenue)
title=f'Comparison of the hotels and revenues'
sns.setstyle('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d58411992996> in <module>
# ----> 1 values,frequencies=np.unique(hotel, revenue)
#       2 title=f'Comparison of the hotels and revenues'
#       3 sns.setstyle('whitegrid')
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     315     ar = np.asanyarray(ar).flatten()
#     316
# --> 317     optional_indices = return_index or return_inverse
#     318
# ...
